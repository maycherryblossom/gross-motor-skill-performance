# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('each_action_eval.csv')

# %%
data_1 = data[data['action'] == 1]

# %%
data_2 = data[data['action'] == 2]

# %%
data_3 = data[data['action'] == 3]

# %%
data_4 = data[data['action'] == 4]

# %%
data_1
# Out:
#      Unnamed: 0  fold  action  weighted_f1_score  micro_f1_score  \
# 0             0     1       1           0.752004        0.750000
# 4             4     2       1           0.778288        0.784483
# 8             8     3       1           0.746853        0.750000
# 12           12     4       1           0.796324        0.801724
# 16           16     5       1           0.779596        0.775862
# 20           20     6       1           0.778471        0.784483
# 24           24     7       1           0.777759        0.775862
# 28           28     8       1           0.790704        0.793103
# 32           32     9       1           0.760953        0.767241
# 36           36    10       1           0.775180        0.784483
# 40           40    11       1           0.758621        0.758621
# 44           44    12       1           0.751126        0.758621
# 48           48    13       1           0.759809        0.767241
# ...

# %%
data_1
# Out:
#      Unnamed: 0  fold  action  weighted_f1_score  micro_f1_score  \
# 0             0     1       1           0.752004        0.750000
# 4             4     2       1           0.778288        0.784483
# 8             8     3       1           0.746853        0.750000
# 12           12     4       1           0.796324        0.801724
# 16           16     5       1           0.779596        0.775862
# 20           20     6       1           0.778471        0.784483
# 24           24     7       1           0.777759        0.775862
# 28           28     8       1           0.790704        0.793103
# 32           32     9       1           0.760953        0.767241
# 36           36    10       1           0.775180        0.784483
# 40           40    11       1           0.758621        0.758621
# 44           44    12       1           0.751126        0.758621
# 48           48    13       1           0.759809        0.767241
# ...

# %%
data_4['accuracy'].mean()
# Out:
# 0.6009070294784581

# %%
data_4['macro_f1_score'].mean()
# Out:
# 0.5995631090728174

# %%
data_4['roc_auc_score'].mean()
# Out:
# 0.7957434774661418

# %%
d = pd.read_csv('result_of_new_label.csv')

# %%
d
# Out:
#     Unnamed: 0  fold  f1_score  roc_auc_score  precision    recall  accuracy  \
# 0            0     1  0.694444       0.891892   0.714286  0.675676  0.786408
# 1            1     2  0.784810       0.919943   0.738095  0.837838  0.834951
# 2            2     3  0.710526       0.876536   0.692308  0.729730  0.786408
# 3            3     4  0.771429       0.933251   0.818182  0.729730  0.844660
# 4            4     5  0.746667       0.894758   0.736842  0.756757  0.815534
# 5            5     6  0.783784       0.923219   0.783784  0.783784  0.844660
# 6            6     7  0.815789       0.912981   0.794872  0.837838  0.864078
# 7            7     8  0.743590       0.906224   0.707317  0.783784  0.805825
# 8            8     9  0.722222       0.901720   0.742857  0.702703  0.805825
# 9            9    10  0.633333       0.913186   0.826087  0.513514  0.786408
# 10          10    11  0.638889       0.841728   0.657143  0.621622  0.747573
# ...

# %%
d.mean()
# Out:
# Unnamed: 0       13.500000
# fold             14.500000
# f1_score          0.736404
# roc_auc_score     0.898254
# precision         0.768236
# recall            0.714286
# accuracy          0.818308
# dtype: float64
